# %%
# !pip install transformers

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/detik_news_title.csv")
df = df[["title"]]
df.rename(columns={"title": "text_data"}, inplace=True)
df
# Out:
#                                                text_data
# 0                         Kemnaker Awasi TKA di Meikarta
# 1                      BNI Digitalkan BNI Java Jazz 2020
# 2      Terbang ke Australia, Edhy Prabowo Mau Genjot ...
# 3      OJK Siapkan Stimulus Ekonomi Antisipasi Dampak...
# 4      Saran Buat Anies-RK yang Mangkir Rapat Banjir ...
# ...                                                  ...
# 91012  Ketumpahan Air Panas di Pesawat, Kamu Bisa Tun...
# 91013  Foto: Bali & 9 Destinasi Paling Instagramable ...
# 91014  Game Bikin Turis Ini Liburan ke Jepang untuk.....
# 91015  Sekeluarga Didepak dari Pesawat, Maskapai Bila...
# 91016  Kapal Raib di Segitiga Bermuda, Nyaris Seabad ...
#
# [91017 rows x 1 columns]

# %%
df = df[df["text_data"].str.split().str.len() > 5]
df
# Out:
#                                                text_data
# 1                      BNI Digitalkan BNI Java Jazz 2020
# 2      Terbang ke Australia, Edhy Prabowo Mau Genjot ...
# 3      OJK Siapkan Stimulus Ekonomi Antisipasi Dampak...
# 4      Saran Buat Anies-RK yang Mangkir Rapat Banjir ...
# 5      RI Bakal Punya Destinasi Wisata Sejarah Islam ...
# ...                                                  ...
# 91012  Ketumpahan Air Panas di Pesawat, Kamu Bisa Tun...
# 91013  Foto: Bali & 9 Destinasi Paling Instagramable ...
# 91014  Game Bikin Turis Ini Liburan ke Jepang untuk.....
# 91015  Sekeluarga Didepak dari Pesawat, Maskapai Bila...
# 91016  Kapal Raib di Segitiga Bermuda, Nyaris Seabad ...
#
# [88642 rows x 1 columns]

# %%
from transformers import pipeline

pretrained_name = "w11wo/indonesian-roberta-base-indolem-sentiment-classifier-fold-0"

nlp = pipeline(
    "sentiment-analysis",
    model=pretrained_name,
    tokenizer=pretrained_name
)

# %%
text_data = df['text_data']
data = []

for i in text_data:
  data.append(nlp(i))

# %%
predicted_label = []
confidence = []

for my_list in data:
  for item in my_list:
    predicted_label.append(item['label'])
    confidence.append(item['score'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['sentiment'] = le.fit_transform(predicted_label)
# Out:
# <ipython-input-45-4689db5f6d73>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'] = le.fit_transform(predicted_label)

# %%
df
# Out:
#                                                text_data  sentiment
# 1                      BNI Digitalkan BNI Java Jazz 2020          0
# 2      Terbang ke Australia, Edhy Prabowo Mau Genjot ...          0
# 3      OJK Siapkan Stimulus Ekonomi Antisipasi Dampak...          1
# 4      Saran Buat Anies-RK yang Mangkir Rapat Banjir ...          0
# 5      RI Bakal Punya Destinasi Wisata Sejarah Islam ...          0
# ...                                                  ...        ...
# 91012  Ketumpahan Air Panas di Pesawat, Kamu Bisa Tun...          0
# 91013  Foto: Bali & 9 Destinasi Paling Instagramable ...          1
# 91014  Game Bikin Turis Ini Liburan ke Jepang untuk.....          1
# 91015  Sekeluarga Didepak dari Pesawat, Maskapai Bila...          0
# 91016  Kapal Raib di Segitiga Bermuda, Nyaris Seabad ...          0
#
# [88642 rows x 2 columns]

# %%
def get_analysis(score):
  if score == 0:
    return 'Negative'
  else:
    return 'Positive'

# %%
df['label'] = df['sentiment'].apply(get_analysis)
# Out:
# <ipython-input-48-b8665fd0312d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['sentiment'].apply(get_analysis)

# %%
df
# Out:
#                                                text_data  sentiment     label
# 1                      BNI Digitalkan BNI Java Jazz 2020          0  Negative
# 2      Terbang ke Australia, Edhy Prabowo Mau Genjot ...          0  Negative
# 3      OJK Siapkan Stimulus Ekonomi Antisipasi Dampak...          1  Positive
# 4      Saran Buat Anies-RK yang Mangkir Rapat Banjir ...          0  Negative
# 5      RI Bakal Punya Destinasi Wisata Sejarah Islam ...          0  Negative
# ...                                                  ...        ...       ...
# 91012  Ketumpahan Air Panas di Pesawat, Kamu Bisa Tun...          0  Negative
# 91013  Foto: Bali & 9 Destinasi Paling Instagramable ...          1  Positive
# 91014  Game Bikin Turis Ini Liburan ke Jepang untuk.....          1  Positive
# 91015  Sekeluarga Didepak dari Pesawat, Maskapai Bila...          0  Negative
# 91016  Kapal Raib di Segitiga Bermuda, Nyaris Seabad ...          0  Negative
#
# [88642 rows x 3 columns]

# %%
df.to_csv("[LABELLED]_detik.csv")
